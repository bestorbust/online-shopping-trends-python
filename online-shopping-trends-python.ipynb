# %% [markdown]
# ## Final Project
#
# **SECTION E _ Data Analysis using Python**
#
#
# **Acknowlegements:** The online shopping data in the year 2019  was collected and published by Jackson Divakar R.
#
# **Team members**:
#
#                  Priyadarshini p
#                  Poorna VM
#                  Mahid ahmad
#                  Nalin koul
#
# blog post:https://www.linkedin.com/posts/priyadarshini-p-23a6b02a2_onlineshopping-ecommercetrends-dataanalysis-activity-7146844543554863104-TSgj?utm_source=share&utm_medium=member_desktop
#
# https://www.linkedin.com/posts/nalin-koul-ba16202a7_title-the-evolution-of-online-shopping-in-activity-7146588477386629120-Ukzm/?utm_source=share&utm_medium=member_desktop
#
# article post:https://www.linkedin.com/posts/priyadarshini-p-23a6b02a2_dataanalysis-python-linkedin-activity-7146805400527380480-6Yo3?utm_source=share&utm_medium=member_desktop

# %% [markdown]
# lets import pandas library for reading the data, manipulation of the data , and data analysis.
#
# matplotlib.pyplot for creating wide range of plots.
#
# seaborn library is for statistical data visualization.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Top fives rows of the data

# %%
df=pd.read_csv("online_shopping.csv")
df.head()
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
# ...

# %% [markdown]
# Bottom fives rows of the data

# %%
df=pd.read_csv("online_shopping.csv")
df.tail()
# Out:
#        Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 52950       52950         NaN    NaN      NaN            NaN             NaN
# 52951       52951         NaN    NaN      NaN            NaN             NaN
# 52952       52952         NaN    NaN      NaN            NaN             NaN
# 52953       52953         NaN    NaN      NaN            NaN             NaN
# 52954       52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date Product_SKU Product_Description      Product_Category  \
# 52950              NaN         NaN                 NaN            Gift Cards
# 52951              NaN         NaN                 NaN  Notebooks & Journals
# 52952              NaN         NaN                 NaN               Android
# 52953              NaN         NaN                 NaN               Android
# 52954              NaN         NaN                 NaN               Android
#
# ...

# %%
df.shape
# Out:
# (52955, 21)

# %% [markdown]
# **shape** is used to get the number of rows anf colums in a dataset
#
# There are 52955 rows and 21 columns.

# %%
df.describe()
# Out:
#          Unnamed: 0   CustomerID  Tenure_Months  Transaction_ID      Quantity  \
# count  52955.000000  52924.00000   52924.000000    52924.000000  52924.000000
# mean   26477.000000  15346.70981      26.127995    32409.825675      4.497638
# std    15286.936089   1766.55602      13.478285     8648.668977     20.104711
# min        0.000000  12346.00000       2.000000    16679.000000      1.000000
# 25%    13238.500000  13869.00000      15.000000    25384.000000      1.000000
# 50%    26477.000000  15311.00000      27.000000    32625.500000      1.000000
# 75%    39715.500000  16996.25000      37.000000    39126.250000      2.000000
# max    52954.000000  18283.00000      50.000000    48497.000000    900.000000
#
#           Avg_Price  Delivery_Charges           GST  Offline_Spend  \
# count  52924.000000      52924.000000  52924.000000   52924.000000
# mean      52.237646         10.517630      0.137462    2830.914141
# ...

# %% [markdown]
#  The **describe** function is used to give the quick  summary of important details about the data. Making it easier to explore and understand key aspects like the average which is nohing but mean , standard deviation, minumum and maximum, 25th ,50th and 75th percentile

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
#        'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
#        'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct'],
#       dtype='object')

# %% [markdown]
# **columns** function is used to get the heading of each column

# %%
df.drop(columns = {'Unnamed: 0','Transaction_ID','Product_Description','Product_SKU','Coupon_Code'}, inplace=True)
df
# Out:
#        CustomerID Gender Location  Tenure_Months Transaction_Date  \
# 0         17850.0      M  Chicago           12.0       2019-01-01
# 1         17850.0      M  Chicago           12.0       2019-01-01
# 2         17850.0      M  Chicago           12.0       2019-01-01
# 3         17850.0      M  Chicago           12.0       2019-01-01
# 4         17850.0      M  Chicago           12.0       2019-01-01
# ...           ...    ...      ...            ...              ...
# 52950         NaN    NaN      NaN            NaN              NaN
# 52951         NaN    NaN      NaN            NaN              NaN
# 52952         NaN    NaN      NaN            NaN              NaN
# 52953         NaN    NaN      NaN            NaN              NaN
# 52954         NaN    NaN      NaN            NaN              NaN
#
#            Product_Category  Quantity  Avg_Price  Delivery_Charges  \
# 0                  Nest-USA       1.0     153.71               6.5
# ...

# %% [markdown]
# The operation we are performing here is the deleting of the unwanted columns which are not neccessary for data analysis . We deleted the columns such as transation id,coupon code and soon.They have no role in data analysis.
#
# The reason of removing the data is to make the dataset look neat and have the only  informations required for analysis
#
# inplace=true means that the changes are applied directly to the original DataFrame, and it does not return a new DataFrame

# %%
df.shape
# Out:
# (52955, 16)

# %% [markdown]
# After the deletion of unwanted colums there are 16 columns remaining.Number of columns are reduced from 21 to 16.

# %%
df.isna().sum()
# Out:
# CustomerID           31
# Gender               31
# Location             31
# Tenure_Months        31
# Transaction_Date     31
# Product_Category      0
# Quantity             31
# Avg_Price            31
# Delivery_Charges     31
# Coupon_Status        31
# GST                  31
# Date                 31
# Offline_Spend        31
# Online_Spend         31
# Month                 0
# Discount_pct        400
# dtype: int64

# %% [markdown]
# isna() is used for checking of missing values , isna returns the boolean values and sum is to return the total number of missing values in a particular column.

# %%
df.dropna(thresh=5, inplace=True)
df
# Out:
#        CustomerID Gender    Location  Tenure_Months Transaction_Date  \
# 0         17850.0      M     Chicago           12.0       2019-01-01
# 1         17850.0      M     Chicago           12.0       2019-01-01
# 2         17850.0      M     Chicago           12.0       2019-01-01
# 3         17850.0      M     Chicago           12.0       2019-01-01
# 4         17850.0      M     Chicago           12.0       2019-01-01
# ...           ...    ...         ...            ...              ...
# 52919     13155.0      F  California            8.0       2019-03-10
# 52920     18077.0      M     Chicago           34.0       2019-03-28
# 52921     16085.0      M  California           15.0       2019-10-06
# 52922     16085.0      M  California           15.0       2019-10-06
# 52923     13659.0      F     Chicago            8.0       2019-10-06
#
#            Product_Category  Quantity  Avg_Price  Delivery_Charges  \
# 0                  Nest-USA       1.0     153.71               6.5
# ...

# %% [markdown]
# df.dropna(thresh=5, inplace=True): dropna method to remove rows with missing values from the Dataset (df). The parameter thresh=5 specifies that a row should be kept if it has at least 5 non-null values. The inplace=True argument means that the changes are applied directly to the original DataFrame, and it does not return a new DataFrame.

# %%
df.isna().sum()
# Out:
# CustomerID          0
# Gender              0
# Location            0
# Tenure_Months       0
# Transaction_Date    0
# Product_Category    0
# Quantity            0
# Avg_Price           0
# Delivery_Charges    0
# Coupon_Status       0
# GST                 0
# Date                0
# Offline_Spend       0
# Online_Spend        0
# Month               0
# Discount_pct        0
# dtype: int64

# %% [markdown]
# After the removal of missing values

# %%
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'])
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
#  Ensure **Transaction_Date** and **Date**  are in datetime format

# %%
category_sales = df.groupby('Product_Category')['Quantity'].sum().sort_values(ascending=True)

# %% [markdown]
#  Here we calculate the total quantity of products sold for each product category in a Dataset. It groups the data by the **Product_Category** column, sums up the **quantities** for each category, and then sorts the results in **ascending order** of total quantity. The variable **category_sales** holds this information.

# %% [markdown]
# #

# %% [markdown]
# ## Which is the highest selling product?
#
# most of our guess would be accessories or makeup.Let's see is our guess is true or not...

# %%
plt.figure(figsize=(12,5))
plt.title('Highest Selling Product Categories')
plt.xlabel('Product Category')
plt.ylabel('Total Sales Quantity')
plt.xticks(rotation=45) 
plt.bar(category_sales.index, category_sales.values)
plt.show()

# %% [markdown]
# When it comes to shopping online most of our guess would be clothes or accessories.considering how popular these items usually are in online shopping.
#
# However,the data revealed a different trend which is office related product . Highest selling product is office related products and not what we expected. Suprisingly,makeup/accessories doesn't top the list. The second most purchased items online is apparel.
#
# This unexpected outcome is likely influenced by the COVID-19 pandemic, as work from home has increased the demand for office supplies. The shift in lifestyle, with more time spent at home, also explains the increased sales in categories like 'Drinkware' and 'Lifestyle.'

# %% [markdown]
# #

# %% [markdown]
# ### Who Shops More Online: Males or Females?
#
#  We're curious about whether there are differences in online shopping preferences based on gender. Our personal belief is that females tend to shop more online than males. Let's find out if our assumption is correct.

# %%
df1=df.Gender.value_counts()
plt.title('Male - Female Purchase Comparision')
plt.pie(df1,labels=['Female','Male'],autopct="%1.1f%%",colors=['pink','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x23873f9a890>,
# ...
#  [Text(-0.4172714865992268, 1.0177841158473988, 'Female'),
#   Text(0.4172714865992264, -1.017784115847399, 'Male')],
#  [Text(-0.22760262905412368, 0.5551549722803993, '62.4%'),
#   Text(0.22760262905412348, -0.5551549722803995, '37.6%')])

# %% [markdown]
#  Looking at  the pie chart, it's clear that females make up the majority of  online shoppers.
# our assumption is correct.

# %% [markdown]
# #

# %% [markdown]
# ### What is the most popular month to shop online?
# lets find out the answer for this..!

# %%
monthly_sales = df['Month'].value_counts()

# %% [markdown]
#   **monthly_sales** will  contain the count of sales transactions for each month.

# %%
plt.figure(figsize=(10, 6))
plt.xlabel('Month')
plt.ylabel('Number of Transactions')
plt.title('Monthly Online Shopping Activity')
plt.xticks(range(1, 13),['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.bar(monthly_sales.index, monthly_sales.values)

plt.show()

# %% [markdown]
# Most popular month for online shopping is August.The increase in sales during August can be explained by various factors such as back-to-school shopping, end-of-summer sales, and people getting ready for upcoming holidays.

# %% [markdown]
# #

# %% [markdown]
# ### What is most popular location in United States to Online Shop in?
#
#  lets find the answer for this by analysising the data.

# %%
location_popularity = df['Location'].value_counts().reset_index()
location_popularity.columns = ['Location', 'Number of Shoppers']

# %% [markdown]
#   **location_popularity** is a DataFrame that shows the popularity of different locations based on the number of shoppers, and it has two columns: 'Location' and 'Number of Shoppers'.

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=location_popularity, y='Number of Shoppers', x='Location')
plt.title('Most Popular Locations for Online Shopping in the United States')
plt.ylabel('Number of Shoppers')
plt.xlabel('Location')
plt.show()

# %% [markdown]
# **Chicago** is the top location for online shopping in the dataset. This suggests that people living in Chicago and the surrounding areas shop online more often than those in other parts of the United States. The trend might be influenced by the harsh winter weather in Chicago, with extremely cold temperatures.

# %% [markdown]
# #

# %% [markdown]
# ### Which month is the online spend more ?

# %%
plt.xlabel('Month')
plt.ylabel('online spend')
plt.title('Monthly Online Shopping Activity')
sns.boxplot(x='Month',y='Online_Spend',data=df)
# Out:
# <Axes: title={'center': 'Monthly Online Shopping Activity'}, xlabel='Month', ylabel='Online_Spend'>

# %% [markdown]
# There are only less number of "outliers" because the prices are appropriate for the category to which they belong Selling through the store or through manual transactions achieves a higher profit.The online spend is high during the month of november as the maximum range is above 4000 and its right skewed.In the month of june the online spend is less and its left skewed

# %% [markdown]
# #

# %% [markdown]
# ### Which month is the offline spend less?

# %%
plt.xlabel('Month')
plt.ylabel('online spend')
plt.title('Monthly Offline Shopping Activity')
plt.xticks(range(1, 13),['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
sns.lineplot(x='Month',y='Offline_Spend',data=df)
# Out:
# <Axes: title={'center': 'Monthly Offline Shopping Activity'}, xlabel='Month', ylabel='online spend'>

# %% [markdown]
# Offline spend in less on the month of may and july and more on the month of december.As we can observe that the graph is not linear and the plot is incresing in particular month and decreasing for particular months.

# %% [markdown]
# ### On which month the delivery charge is less and more?

# %%
plt.figure(figsize=(10, 6))
plt.xlabel('Month')
plt.ylabel('online spend')
plt.title('Monthly Delivery charge Activity')
sns.barplot(data=df,x='Month',y='Delivery_Charges')
plt.show()

# %% [markdown]
# In the month of february  the delivery charge is high its between 14-16 and
# In the month of november the delivery chare is less compared to other month its between 8-10.

# %% [markdown]
# ### What is the relation between the Average price and the Quantity?

# %%
sns.scatterplot(x = "Avg_Price", y = "Quantity", data =df)
plt.title("Relation between Average price and Quantity")
plt.show()

# %% [markdown]
# Average price increases, the quantity sold decreases.
# There is an inverse relationship between quantity and average price.

# %% [markdown]
# #

# %% [markdown]
# ### Who spends more on online and offline:Male or Female?

# %%
sns.boxplot(data=df,x='Gender',y='Offline_Spend')
plt.title("Gender Vs Offline spend")
plt.show()
sns.boxplot(data=df,x='Gender',y='Online_Spend')
plt.title("Gender Vs Online spend")
plt.show()

# %% [markdown]
# The offline spend of male is right skewed or positive skewed . the 50th percentile also known as median,indicates that half of the data fall below the range 3000-4000, and the other half is above it.In the offline spend of women the outliers below  the minimum range.
#
# The Online spend of male and female both are almost same and we can observe there is a normal distribution and there are equal number of ouliers too.

# %%
plt.figure(figsize=(12,5))
plt.title("relation btw product category and avg price")
plt.xticks(rotation=90)
sns.barplot(data=df, x='Product_Category', y='Avg_Price')
# Out:
# <Axes: title={'center': 'relation btw product category and avg price'}, xlabel='Product_Category', ylabel='Avg_Price'>

# %%
df.skew()
# Out:
# C:\Users\sys 1\AppData\Local\Temp\ipykernel_6156\1665899112.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# CustomerID          -0.031844
# Tenure_Months       -0.070145
# Quantity            19.014684
# Avg_Price            1.625805
# Delivery_Charges    11.990339
# GST                 -0.352441
# Offline_Spend       -0.318186
# Online_Spend         0.453747
# Month               -0.073858
# Discount_pct         0.008564
# dtype: float64

# %%
df.kurt()
# Out:
# C:\Users\sys 1\AppData\Local\Temp\ipykernel_6156\1257127604.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.kurt()
# CustomerID           -1.235418
# Tenure_Months        -1.116241
# Quantity            523.620250
# Avg_Price             3.310494
# Delivery_Charges    206.179663
# GST                  -1.396011
# Offline_Spend         0.104594
# Online_Spend         -0.147990
# Month                -1.091895
# Discount_pct         -1.486007
# dtype: float64

# %% [markdown]
# **Result of online shopping dataset**
# **Gender**: The majority of customers are female.
#
#
# **Location**: The highest number of customers are from Chicago.
#
#
# **Product_category**: The highest sales are attributed to the office product category.
#
#
# **Quantity**: The distribution of quantities ordered is positively skewed, indicating that most people order small amounts, but a few buy a lot.This could mean many individual customers are buying, and some businesses might be making large bulk purchases.
#
#
# **Avg_Price**: Most categories have a reasonable average price for their products.
#
#
# **Offline_Spend and Online_Spend**: Selling in person usually makes more money than selling online.
#
#
# **Month**: Most sales occurred in the august(8th) month.
